# %%
import numpy as np

# %%
a = np.array([1,2,3])
print(a*2)
# Out:
# [2 4 6]

# %%
b = np.array([3,4,5])
multi = a*b
print(multi)
# Out:
# [ 3  8 15]

# %%
sum = a+b
print(sum)
# Out:
# [4 6 8]

# %%
c = np.array([[1,2,3],[4,5,6]])
print(c)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
np.mean(c)
# Out:
# 3.5

# %%
np.median(c)
# Out:
# 3.5

# %%
d = np.array([1,2,3,4,5,6,6,6,7,8])

# %%
np.count_nonzero(d)
# Out:
# 10

# %%
print(np.mean(d), np.median(d))
# Out:
# 4.8 5.5

# %%
np.square(d)
# Out:
# array([ 1,  4,  9, 16, 25, 36, 36, 36, 49, 64])

# %%
import matplotlib.pyplot as plt

# %%
print(d)
plt.plot(d)
# Out:
# [1 2 3 4 5 6 6 6 7 8]

# %%
c
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
plt.plot(c)

# %%
plt.plot([1,2,3],[4,5,6])

# %%
x =[1,2,3]
y = [4,5,6]
plt.plot(x,y)

# %%
x = [1,2,3]*2

# %%
x
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
x = np.array([1,2,3]) * 2
x
# Out:
# array([2, 4, 6])

# %%
import seaborn as sns
